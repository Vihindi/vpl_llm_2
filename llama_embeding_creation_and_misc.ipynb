# %%
# 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/vpl_llm_2/
# !ls -F
# Out:
# /content/drive/MyDrive/vpl_llm_2
# args/
# baseline_bash.sh
# convert_user_data.py
# create_multi_persona_simulation.py
# custom_vpl_generation.ipynb
# data/
# evaluate_adaptation_velocity.py
# evaluate_reward_scores.py
# FYP_VPL_V1.ipynb
# generate_llm_embeddings_grouped_personas.sh
# generate_llm_embeddings_personas_ab.sh
# GPT_2_emebeding_creation.ipynb
# hidden_context/
# llama_embeding_creation.ipynb
# logs/
# __pycache__/
# results/
# run_all_drift_evals.py
# run_generation.py
# sigma_sanity_check.py
# Simulation.ipynb
# simulation_plot.png
# simulation_plot_reward_fluctuation.png
# simulation_reward_fluctuation.png
# submit_job_grouped_personas.sh
# submit_job_personas_ab.sh
# temp_gpt2_embed_file.sh
# temp_gpt2_run.sh
# temp_llama_run.sh
# vae_session_inference.py
# vpl_args_eval.png
# wandb/

# %% [markdown]
# "logs/FYP_final/grouped_personas_2_witouth_MMP_with_Film_llama_VPL"

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vihindikotalawala (vihindikotalawala-robert-gordon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Embeding generation wit mask mean pooling llama

# %%
# !bash generate_llm_embeddings_grouped_personas.sh
# Out:
# Processing subsets: Persona_A Persona_B Persona_C Persona_D Persona_E
# Processing Persona_A with model llama3...
# [DEBUG] CWD: /content/drive/MyDrive/vpl_llm_2
# [DEBUG] Checking train path: data/emb_grouped_personas_Without_MMP_/llama3/Persona_A/train.jsonl
# [DEBUG] Absolute path: /content/drive/MyDrive/vpl_llm_2/data/emb_grouped_personas_Without_MMP_/llama3/Persona_A/train.jsonl
# [DEBUG] File NOT FOUND
# ScriptArguments(output_dir='data/emb_grouped_personas_Without_MMP_/', data_path='data/grouped_data_converted', data_subset='Persona_A', data_split='train', dataset_size=0, model_type='llama3', model_name_or_path='/content/drive/MyDrive/models/llama-3-8b-instruct', embed_dim=1024, max_length=1024, with_embeddings=True, synthetic_dataset=False, other_subsets='grouped_personas', survey_size=100, context_length=8, controversial_only=False, num_duplicates=2, fixed_context_length=False, random_contexts=True)
# Generating train split: 15600 examples [00:01, 9729.97 examples/s]
# ...

# %% [markdown]
# ## Embeding generation without mask mean pooling llama

# %%
# !bash generate_llm_embeddings_grouped_personas.sh
# Out:
# Processing subsets: Persona_A Persona_B Persona_C Persona_D Persona_E
# Processing Persona_A with model llama3...
# [DEBUG] CWD: /content/drive/MyDrive/vpl_llm_2
# [DEBUG] Checking train path: data/emb_grouped_personas_Without_MMP_/llama3/Persona_A/train.jsonl
# [DEBUG] Absolute path: /content/drive/MyDrive/vpl_llm_2/data/emb_grouped_personas_Without_MMP_/llama3/Persona_A/train.jsonl
# [DEBUG] File NOT FOUND
# ScriptArguments(output_dir='data/emb_grouped_personas_Without_MMP_/', data_path='data/grouped_data_converted', data_subset='Persona_A', data_split='train', dataset_size=0, model_type='llama3', model_name_or_path='/content/drive/MyDrive/models/llama-3-8b-instruct', embed_dim=1024, max_length=1024, with_embeddings=True, synthetic_dataset=False, other_subsets='grouped_personas', survey_size=100, context_length=8, controversial_only=False, num_duplicates=2, fixed_context_length=False, random_contexts=True)
# Generating train split: 15600 examples [00:01, 9729.97 examples/s]
# ...

# %% [markdown]
# ## Benchmarking original vpl

# %%
# !bash temp_gpt2_run.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.4713', 'train_kld': '0.004221', 'train_accuracy': '1', 'rewards_chosen': '-0.8828', 'rewards_rejected': '-1.57', 'embeddings_chosen': '0.4238', 'embeddings_rejected': '0.4121', 'mean': '-0.03317', 'log_var': '-0.1639', 'epoch': '1.874'}
# {'train_recon_loss': '0.4534', 'train_kld': '0.004941', 'train_accuracy': '1', 'rewards_chosen': '1.473', 'rewards_rejected': '0.875', 'embeddings_chosen': '0.4238', 'embeddings_rejected': '0.416', 'mean': '-0.02894', 'log_var': '-0.1645', 'epoch': '1.874'}
# {'train_recon_loss': '0.806', 'train_kld': '0.002818', 'train_accuracy': '0.25', 'rewards_chosen': '-0.5', 'rewards_rejected': '-0.293', 'embeddings_chosen': '0.4316', 'embeddings_rejected': '0.4316', 'mean': '-0.03691', 'log_var': '-0.1762', 'epoch': '1.874'}
# ...

# %%
# !bash temp_llama_run.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.6056', 'train_kld': '0.004779', 'train_scaled_kld': '1.232e-06', 'train_accuracy': '0.75', 'rewards_chosen': '0.1092', 'rewards_rejected': '-0.09814', 'embeddings_chosen': '0.009583', 'embeddings_rejected': '0.01611', 'mean': '-1.665e-05', 'log_var': '-3.823e-05', 'epoch': '1.878'}
# {'train_recon_loss': '0.5907', 'train_kld': '0.003576', 'train_scaled_kld': '9.225e-07', 'train_accuracy': '0.75', 'rewards_chosen': '0.9626', 'rewards_rejected': '0.724', 'embeddings_chosen': '0.05688', 'embeddings_rejected': '0.04688', 'mean': '6.115e-05', 'log_var': '1.108e-05', 'epoch': '1.878'}
# {'train_recon_loss': '0.6927', 'train_kld': '0.004296', 'train_scaled_kld': '1.109e-06', 'train_accuracy': '0.75', 'rewards_chosen': '-0.2373', 'rewards_rejected': '-0.2412', 'embeddings_chosen': '0.03638', 'embeddings_rejected': '0.02734', 'mean': '-5.618e-05', 'log_var': '5.445e-06', 'epoch': '1.878'}
# ...

# %%
# !bash temp_llama_run.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
#  88% 177/200 [00:11<00:01, 15.22it/s]
#  90% 179/200 [00:11<00:01, 15.84it/s]
#  90% 181/200 [00:11<00:01, 16.60it/s]
#  92% 183/200 [00:11<00:01, 16.06it/s]
#  92% 185/200 [00:12<00:00, 15.02it/s]
#  94% 188/200 [00:12<00:00, 17.70it/s]
#  95% 190/200 [00:12<00:00, 17.04it/s]
#  96% 193/200 [00:12<00:00, 17.92it/s]
#  98% 195/200 [00:12<00:00, 17.15it/s]
#  98% 197/200 [00:12<00:00, 17.36it/s]
#
# {'eval_loss': '0.6669', 'eval_accuracy': '0.63', 'eval_kld': '388.7', 'eval_runtime': '13.46', 'eval_samples_per_second': '14.86', 'eval_steps_per_second': '14.86', 'epoch': '1.7'}
#  85% 3315/3900 [1:48:52<18:47,  1.93s/it]
# 100% 200/200 [00:13<00:00, 16.59it/s]
# ...
