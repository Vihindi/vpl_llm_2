# %%
# 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/vpl_llm_2/
# !ls -F
# Out:
# /content/drive/MyDrive/vpl_llm_2
# args/
# baseline_bash.sh
# convert_user_data.py
# create_multi_persona_simulation.py
# custom_vpl_generation.ipynb
# data/
# evaluate_adaptation_velocity.py
# evaluate_reward_scores.py
# FYP_VPL_V1.ipynb
# generate_llm_embeddings_grouped_personas.sh
# generate_llm_embeddings_personas_ab.sh
# GPT_2_emebeding_creation.ipynb
# hidden_context/
# llama_embeding_creation.ipynb
# logs/
# __pycache__/
# results/
# run_all_drift_evals.py
# run_generation.py
# sigma_sanity_check.py
# Simulation.ipynb
# simulation_plot.png
# simulation_plot_reward_fluctuation.png
# simulation_reward_fluctuation.png
# submit_job_grouped_personas.sh
# submit_job_personas_ab.sh
# temp_gpt2_embed_file.sh
# temp_gpt2_run.sh
# temp_llama_run.sh
# vae_session_inference.py
# vpl_args_eval.png
# wandb/

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2

# %% [markdown]
# ## Embeding generation with MMP GPT2

# %%
# !bash generate_llm_embeddings_grouped_personas.sh
# Out:
# Processing subsets: Persona_A Persona_B Persona_C Persona_D Persona_E
# Processing Persona_A with model gpt2...
# [DEBUG] CWD: /content/drive/MyDrive/vpl_llm_2
# [DEBUG] Checking train path: data/gpt_2_emb_grouped_personas_100/gpt2/Persona_A/train.jsonl
# [DEBUG] Absolute path: /content/drive/MyDrive/vpl_llm_2/data/gpt_2_emb_grouped_personas_100/gpt2/Persona_A/train.jsonl
# [DEBUG] File EXISTS
# Skipping Persona_A train split as it already exists.
# [DEBUG] Checking test path: data/gpt_2_emb_grouped_personas_100/gpt2/Persona_A/test.jsonl
# [DEBUG] Absolute path: /content/drive/MyDrive/vpl_llm_2/data/gpt_2_emb_grouped_personas_100/gpt2/Persona_A/test.jsonl
# [DEBUG] File EXISTS
# Skipping Persona_A test split as it already exists.
# Processing Persona_B with model gpt2...
# [DEBUG] CWD: /content/drive/MyDrive/vpl_llm_2
# [DEBUG] Checking train path: data/gpt_2_emb_grouped_personas_100/gpt2/Persona_B/train.jsonl
# ...

# %% [markdown]
# ## Embeding Generation without MMP gpt2

# %%
# !bash generate_llm_embeddings_grouped_personas.sh
# Out:
# Processing subsets: Persona_A Persona_B Persona_C Persona_D Persona_E
# Processing Persona_A with model gpt2...
# [DEBUG] CWD: /content/drive/MyDrive/vpl_llm_2
# [DEBUG] Checking train path: data/gpt_2_emb_grouped_personas_without_MMP_100/gpt2/Persona_A/train.jsonl
# [DEBUG] Absolute path: /content/drive/MyDrive/vpl_llm_2/data/gpt_2_emb_grouped_personas_without_MMP_100/gpt2/Persona_A/train.jsonl
# [DEBUG] File NOT FOUND
# ScriptArguments(output_dir='data/gpt_2_emb_grouped_personas_without_MMP_100/', data_path='data/grouped_data_converted', data_subset='Persona_A', data_split='train', dataset_size=0, model_type='gpt2', model_name_or_path='/content/drive/MyDrive/models/gpt2', embed_dim=1024, max_length=1024, with_embeddings=True, synthetic_dataset=False, other_subsets='grouped_personas', survey_size=100, context_length=8, controversial_only=False, num_duplicates=2, fixed_context_length=False, random_contexts=True)
# Generating train split: 15600 examples [00:01, 9757.44 examples/s]
# ...

# %% [markdown]
# # Benchmarking

# %% [markdown]
# ## BTL

# %%
# !bash submit_job_grouped_personas.sh base
# Out:
# Streaming output truncated to the last 5000 lines.
# {'rewards_chosen': '-2.076', 'rewards_rejected': '-2.209', 'epoch': '1.874'}
# {'rewards_chosen': '-2.457', 'rewards_rejected': '-2.473', 'epoch': '1.874'}
# {'rewards_chosen': '-2.053', 'rewards_rejected': '-2.035', 'epoch': '1.874'}
# {'rewards_chosen': '-2.01', 'rewards_rejected': '-1.939', 'epoch': '1.874'}
# {'rewards_chosen': '-2.203', 'rewards_rejected': '-2.314', 'epoch': '1.874'}
# {'rewards_chosen': '-1.969', 'rewards_rejected': '-1.861', 'epoch': '1.874'}
# {'rewards_chosen': '-2.143', 'rewards_rejected': '-2.078', 'epoch': '1.874'}
# {'rewards_chosen': '-2.064', 'rewards_rejected': '-2.1', 'epoch': '1.874'}
# {'rewards_chosen': '-2.363', 'rewards_rejected': '-2.309', 'epoch': '1.874'}
# {'rewards_chosen': '-2.207', 'rewards_rejected': '-2.25', 'epoch': '1.874'}
# {'rewards_chosen': '-2.076', 'rewards_rejected': '-2.025', 'epoch': '1.874'}
# {'rewards_chosen': '-2.008', 'rewards_rejected': '-2.039', 'epoch': '1.874'}
# ...

# %% [markdown]
# ## DPL - Categorical

# %%
# !bash submit_job_grouped_personas.sh categorical
# Out:
# Streaming output truncated to the last 5000 lines.
# {'rewards_chosen': '6.438', 'rewards_rejected': '6.388', 'epoch': '1.874'}
# {'rewards_chosen': '6.425', 'rewards_rejected': '6.425', 'epoch': '1.874'}
# {'rewards_chosen': '6.35', 'rewards_rejected': '6.22', 'epoch': '1.874'}
# {'rewards_chosen': '6.827', 'rewards_rejected': '6.758', 'epoch': '1.874'}
# {'rewards_chosen': '6.572', 'rewards_rejected': '6.36', 'epoch': '1.874'}
# {'rewards_chosen': '6.484', 'rewards_rejected': '6.438', 'epoch': '1.874'}
# {'rewards_chosen': '6.391', 'rewards_rejected': '6.365', 'epoch': '1.874'}
# {'rewards_chosen': '6.529', 'rewards_rejected': '6.477', 'epoch': '1.874'}
# {'rewards_chosen': '6.693', 'rewards_rejected': '6.6', 'epoch': '1.874'}
# {'rewards_chosen': '6.47', 'rewards_rejected': '6.393', 'epoch': '1.874'}
# {'rewards_chosen': '6.618', 'rewards_rejected': '6.728', 'epoch': '1.874'}
# {'rewards_chosen': '6.453', 'rewards_rejected': '6.486', 'epoch': '1.874'}
# ...

# %% [markdown]
# ## DPL - mean and variance

# %%
# !bash submit_job_grouped_personas.sh mean_and_variance
# Out:
# Streaming output truncated to the last 5000 lines.
# {'rewards_chosen': '-1.453', 'rewards_rejected': '-1.494', 'epoch': '1.874'}
# {'rewards_chosen': '-1.188', 'rewards_rejected': '-1.175', 'epoch': '1.874'}
# {'rewards_chosen': '-0.979', 'rewards_rejected': '-0.9871', 'epoch': '1.874'}
# {'rewards_chosen': '-1.177', 'rewards_rejected': '-1.261', 'epoch': '1.874'}
# {'rewards_chosen': '-0.877', 'rewards_rejected': '-0.8533', 'epoch': '1.874'}
# {'rewards_chosen': '-1.156', 'rewards_rejected': '-1.15', 'epoch': '1.874'}
# {'rewards_chosen': '-0.8696', 'rewards_rejected': '-0.8953', 'epoch': '1.874'}
# {'rewards_chosen': '-1.305', 'rewards_rejected': '-1.247', 'epoch': '1.874'}
# {'rewards_chosen': '-1.364', 'rewards_rejected': '-1.399', 'epoch': '1.874'}
# {'rewards_chosen': '-0.9634', 'rewards_rejected': '-0.9169', 'epoch': '1.874'}
# {'rewards_chosen': '-1.022', 'rewards_rejected': '-1.067', 'epoch': '1.874'}
# ...

# %% [markdown]
# ## Ablation study training

# %% [markdown]
# Train Vae without film gpt2

# %%
# !bash submit_job_grouped_personas.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.6573', 'train_kld': '0.01096', 'train_scaled_kld': '1.094e-05', 'train_accuracy': '0.5', 'rewards_chosen': '0.4143', 'rewards_rejected': '0.3374', 'embeddings_chosen': '0.4141', 'embeddings_rejected': '0.416', 'mean': '7.644e-05', 'log_var': '3.844e-05', 'epoch': '1.687'}
# {'train_recon_loss': '0.7489', 'train_kld': '0.01092', 'train_scaled_kld': '1.091e-05', 'train_accuracy': '0', 'rewards_chosen': '0.4522', 'rewards_rejected': '0.5602', 'embeddings_chosen': '0.4082', 'embeddings_rejected': '0.4141', 'mean': '-9.35e-06', 'log_var': '3.872e-06', 'epoch': '1.687'}
# {'train_recon_loss': '0.719', 'train_kld': '0.009604', 'train_scaled_kld': '9.589e-06', 'train_accuracy': '0.25', 'rewards_chosen': '0.25', 'rewards_rejected': '0.2934', 'embeddings_chosen': '0.4082', 'embeddings_rejected': '0.3965', 'mean': '5.905e-05', 'log_var': '0.0001196', 'epoch': '1.687'}
# ...

# %% [markdown]
# Train vae without MMP and FiLM

# %%
# !bash submit_job_grouped_personas.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.6711', 'train_kld': '0.08122', 'train_scaled_kld': '8.109e-05', 'train_accuracy': '0.75', 'rewards_chosen': '0.01538', 'rewards_rejected': '-0.03186', 'embeddings_chosen': '0.3965', 'embeddings_rejected': '0.4434', 'mean': '-0.000416', 'log_var': '0.0001256', 'epoch': '1.688'}
# {'train_recon_loss': '0.7048', 'train_kld': '0.05502', 'train_scaled_kld': '5.493e-05', 'train_accuracy': '0', 'rewards_chosen': '0.1542', 'rewards_rejected': '0.1774', 'embeddings_chosen': '0.3711', 'embeddings_rejected': '0.3848', 'mean': '-7.629e-05', 'log_var': '-6.943e-05', 'epoch': '1.688'}
# {'train_recon_loss': '0.6864', 'train_kld': '0.08238', 'train_scaled_kld': '8.224e-05', 'train_accuracy': '0.75', 'rewards_chosen': '0.2612', 'rewards_rejected': '0.2476', 'embeddings_chosen': '0.25', 'embeddings_rejected': '0.2617', 'mean': '-0.0004535', 'log_var': '-0.0001495', 'epoch': '1.688'}
# ...

# %% [markdown]
# "logs/FYP_final/grouped_personas_2_gpt_2_vpl_with_MMP_n_Film"

# %%
# !bash submit_job_grouped_personas.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.6047', 'train_kld': '325.4', 'train_scaled_kld': '0.0009746', 'train_accuracy': '0.75', 'rewards_chosen': '-1.157', 'rewards_rejected': '-1.366', 'embeddings_chosen': '0.4238', 'embeddings_rejected': '0.4219', 'mean': '0.06204', 'log_var': '-0.3724', 'epoch': '1.687'}
# {'train_recon_loss': '0.5989', 'train_kld': '325.2', 'train_scaled_kld': '0.000974', 'train_accuracy': '1', 'rewards_chosen': '-0.7246', 'rewards_rejected': '-0.9268', 'embeddings_chosen': '0.4277', 'embeddings_rejected': '0.4199', 'mean': '0.06191', 'log_var': '-0.3718', 'epoch': '1.687'}
# {'train_recon_loss': '0.6231', 'train_kld': '326', 'train_scaled_kld': '0.0009765', 'train_accuracy': '0.75', 'rewards_chosen': '-1.534', 'rewards_rejected': '-1.688', 'embeddings_chosen': '0.4062', 'embeddings_rejected': '0.4121', 'mean': '0.06217', 'log_var': '-0.3738', 'epoch': '1.687'}
# ...

# %% [markdown]
# "logs/FYP_final/grouped_personas_2_gpt_2_vpl_without_MMP_with_Film"

# %%
# !bash submit_job_grouped_personas.sh vae
# Out:
# Streaming output truncated to the last 5000 lines.
# {'train_recon_loss': '0.6802', 'train_kld': '139.7', 'train_scaled_kld': '0.0004183', 'train_accuracy': '1', 'rewards_chosen': '-0.0379', 'rewards_rejected': '-0.06406', 'embeddings_chosen': '0.4004', 'embeddings_rejected': '0.4043', 'mean': '0.02331', 'log_var': '0.03681', 'epoch': '1.688'}
# {'train_recon_loss': '0.7039', 'train_kld': '114.9', 'train_scaled_kld': '0.0003441', 'train_accuracy': '0.25', 'rewards_chosen': '-0.2294', 'rewards_rejected': '-0.2081', 'embeddings_chosen': '0.4922', 'embeddings_rejected': '0.4648', 'mean': '0.0202', 'log_var': '0.03076', 'epoch': '1.688'}
# {'train_recon_loss': '0.6735', 'train_kld': '124.6', 'train_scaled_kld': '0.0003732', 'train_accuracy': '0.75', 'rewards_chosen': '-0.02603', 'rewards_rejected': '-0.06628', 'embeddings_chosen': '0.377', 'embeddings_rejected': '0.4062', 'mean': '0.0212', 'log_var': '0.0323', 'epoch': '1.688'}
# ...
